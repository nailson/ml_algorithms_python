# %% [markdown]
# ## Test Least Squares Regression

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
sys.path.append('..')
from least_squares_regression import LeastSquaresRegression

# %%
X = 2 * np.random.rand(100) 
y = 4 + 3 * X + np.random.randn(100)

data = pd.DataFrame({'covariate':X, 'response':y})

plt.scatter(X, y)

# %%
lr_model = LeastSquaresRegression()
lr_model.fit(data.covariate, data.response)

# %%
print("Intercept: {}\nSlope: {}".format(lr_model.intercept, lr_model.slope))
# Out:
# Intercept: 4.128592247973376
# Slope: 2.7149573251323256

# %%
y_pred = lr_model.predict(X)

plt.scatter(X,y)
plt.plot(X, y_pred, color='red')

# %%
data
# Out:
#     covariate  response
# 0    1.876366  9.166326
# 1    0.874391  8.783030
# 2    1.941275  9.246522
# 3    0.109842  4.500405
# 4    0.685976  5.675634
# ..        ...       ...
# 95   1.709931  7.442505
# 96   0.960478  7.573865
# 97   0.408393  4.054086
# 98   1.753575  8.907972
# 99   0.447082  5.019660
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Comparing to Sklearn LinearRegression

# %%
from sklearn.linear_model import LinearRegression

X_test = data[['covariate']]
y_test = data[['response']]

lm_sklearn = LinearRegression()
lm_sklearn.fit(X_test, y_test)

print("Intercept: {}\nSlope: {}".format(lm_sklearn.intercept_, lm_sklearn.coef_))
# Out:
# Intercept: [4.12859225]
# Slope: [[2.71495733]]
